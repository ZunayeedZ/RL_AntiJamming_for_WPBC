# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as pyl
from math import pi

#RF Incident
Ac = 1 #amplitude of the incident RF signal from AP
fc = 2.46*10**3 #Carrier frequency 2.462GHz, reference: "HitchHike: Practical Backscatter Using Commodity WiFi"fs = eval(input('Enter the sampling frequency: ')) #fs >= 2fm (Sampling theorem)
t = np.arange(-0.25,0.25,1*10**-3) #min,max,step size
x = Ac*np.cos(2*pi*fc*t) #RF incident signal from AP
plt.subplot(1, 3, 1)
plt.plot(t,x)

#BPSK backscattered signal
Ac = 1 #amplitude of the incident RF signal from AP
fc = 2.46*10**3 #Carrier frequency 2.462GHz, reference: "HitchHike: Practical Backscatter Using Commodity WiFi"fs = eval(input('Enter the sampling frequency: ')) #fs >= 2fm (Sampling theorem)
t = np.arange(-0.25,0.25,1*10**-3) #min,max,step size
x = Ac*np.cos(2*pi*fc*t) #RF incident signal from AP
plt.subplot(1, 3, 1)
plt.plot(t,x)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show
plt.grid()
